# %% [markdown]
# # **This notenook contains solved excersie question of the book [Hands on Machine Learning with Scikit-Learn, Keras & TensorFlow](https://www.oreilly.com/library/view/hands-on-machine-learning/9781492032632/) chapter-4 Traning Models...!**

# %% [markdown]
# ### **Q1. What is the fundamental idea behind Support Vector Machines?<br>**

# %% [markdown]
# ### **Q2. What is a support vector?<br>**

# %% [markdown]
# ### **Q3. Why is it important to scale the inputs when using SVM?<br>**

# %% [markdown]
# ### **Q4. Can an SVM classifier output a confidence score when it classifies an instance ? What about a probability<br>**

# %% [markdown]
# ### **Q5. Should you use the primal or the dual form of the SVM problem to train a model on a training set with millions of instances and hundreds of features?<br>**

# %% [markdown]
# ### **Q6. Say you’ve trained an SVM classifier with an RBF kernel, but it seems to underfit the training set. Should you increase or decrease γ (gamma)? What about C?<br>**

# %% [markdown]
# ### **Q7. How should you set the QP parameters (H, f, A, and b) to solve the soft margin linear SVM classifier problem using an off-the-shelf QP solver?<br>**

# %% [markdown]
# ### **Q8. Train a LinearSVC on a linearly separable dataset. Then train an SVC and a SGDClassifier on the same dataset. See if you can get them to produce roughly the same model.<br>**

# %% [markdown]
# ### **Q9. Train an SVM classifier on the MNIST dataset. Since SVM classifiers are binary classifiers, you will need to use one-versus-the-rest to classify all 10 digits. You may want to tune the hyperparameters using small validation sets to speed up the process. What accuracy can you reach?<br>**

# %% [markdown]
# ### **Q10. Train an SVM regressor on the California housing dataset.<br>**
