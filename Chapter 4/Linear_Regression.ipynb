# %% [markdown]
# if we consider a linear regression model there are two ways to traina Linear Regression moel they are
# 1. using direct "closed-form" equation that directly computes the model parameters that perfectly fits the traning set
# 2. using an iterative optimization approach called gradient descent (GD) that gradually twearks the model to the best parameters as the first method
#
# linear regression is used on linear datasets where are Polynomial regression model  is used on non linear regression models
#
# linear regression model basicly is the sum of weighted features and added bias term
#
# y_hat=b0+b1*x1+b2*x2+....bn*xn
#
# where
# y_hat is predicted value
# b0 is bias
# xi is feature i
# bi is model parameter
#
# in vector form
# y_hat=h0(X)=0.X
# . is dot product

# %% [markdown]
# model traning part
#
# as the model is s Regression miodel we need a evalutaion metric
# we need RMSE(Root Mean Square Error)
#
# to train our model we simply need  find the value of 0 to minimize our MSE.

# %% [markdown]
# MSE
