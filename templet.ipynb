# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Regression case
corr_with_target = df.corr(numeric_only=True)['MEDV'].abs().sort_values(ascending=False)
print(corr_with_target)

# For classification
from sklearn.feature_selection import mutual_info_classif
mi_scores = mutual_info_classif(X, y)
mi = pd.Series(mi_scores, index=X.columns).sort_values(ascending=False)
print(mi.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-453758689.py in <cell line: 0>()
#       1 # Regression case
# ----> 2 corr_with_target = df.corr(numeric_only=True)['MEDV'].abs().sort_values(ascending=False)
#       3 print(corr_with_target)
#       4
#       5 # For classification
#
# NameError: name 'df' is not defined
